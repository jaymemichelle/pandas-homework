# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Reading whale returns

whale_returns = Path("C:/Users/dejay/Documents/UofT/Fintech Bootcamp/pandas-homework/pandas-homework/whale_returns.csv")

df = pd.read_csv(whale_returns, index_col="Date", parse_dates=True, infer_datetime_format=True)

df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
df.dropna(inplace=True)

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns

algorithmic_returns = Path("C:/Users/dejay/Documents/UofT/Fintech Bootcamp/pandas-homework/pandas-homework/algo_returns.csv")

ar_df = pd.read_csv(algorithmic_returns, index_col="Date", parse_dates=True, infer_datetime_format=True)

ar_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
ar_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
ar_df.dropna(inplace=True)

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices

s_p = Path("C:/Users/dejay/Documents/UofT/Fintech Bootcamp/pandas-homework/pandas-homework/sp_tsx_history.csv")

sp_df = pd.read_csv(s_p, index_col="Date", parse_dates=True, infer_datetime_format=True)

sp_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_df['Close'] =sp_df['Close'].replace(r'[$,]','',regex=True).astype('float64')
sp_df.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
sp_daily = sp_df.pct_change()

# %%
# Drop nulls
sp_daily=sp_daily.dropna().copy()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_daily.columns = ["sp"]
sp_daily.head()
# Out:
#                   sp
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combine_returns = pd.concat([df, ar_df, sp_daily], axis="columns", join="inner")
combine_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2        sp
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combine_returns.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (combine_returns + 1).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20, 10), title="Cumulative Returns", grid=True)
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combine_returns.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combine_returns.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# sp                             0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp_daily.std()

# Determine which portfolios are riskier than the S&P TSX 60
sp_daily = combine_returns["sp"].std()
combine_returns.std() > sp_daily
# Out:
# SOROS FUND MANAGEMENT LLC       True
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                          True
# Algo 2                          True
# sp                             False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_deviation = df, ar_df, sp_daily * np.sqrt(252)
annualized_deviation
# Out:
# (            SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
#  Date
#  2015-03-03                  -0.001266           -0.004981
#  2015-03-04                   0.002230            0.003241
#  2015-03-05                   0.004016            0.004076
#  2015-03-06                  -0.007905           -0.003574
#  2015-03-09                   0.000582            0.004225
#  ...                               ...                 ...
#  2019-04-25                  -0.000285           -0.001291
#  2019-04-26                   0.008149            0.009162
#  2019-04-29                   0.001254            0.002719
#  2019-04-30                  -0.001295           -0.002211
#  2019-05-01                  -0.005847           -0.001341
#
#              TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
#  Date
#  2015-03-03                    -0.000496               -0.006569
#  2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

# Plot the rolling standard deviation
combine_returns.rolling(window=21).std().plot(figsize=[20,10])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

# Display de correlation matrix
combine_returns.corr().plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
single_covariance = combine_returns['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combine_returns['sp'])

# Calculate variance of S&P TSX
sp_covariance = combine_returns['sp'].rolling(window=60).var()

# Computing beta
computing_beta = single_covariance/sp_covariance

# Plot beta trend
computing_beta.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combine_returns.ewm(halflife=21).std().head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# 2015-03-05                     0.002478                0.007020  0.004162
# 2015-03-06                     0.004665                0.009387  0.003419
# 2015-03-09                     0.005496                0.008066  0.002999
#
#               Algo 2        sp
# Date
# 2015-03-03       NaN       NaN
# 2015-03-04  0.002380  0.003648
# 2015-03-05  0.002662  0.004936
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sh_ratios = (combine_returns.mean() * 252) / (combine_returns.std() * np.sqrt(252))
sh_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# sp                             0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sh_ratios.plot(kind = 'bar', title='sh ratio')
# Out:
# <AxesSubplot:title={'center':'sh ratio'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock - Gamestop
gme_stock = Path("C:/Users/dejay/Documents/UofT/Fintech Bootcamp/pandas-homework/pandas-homework/gamestop.csv")

gme_df = pd.read_csv(gme_stock, parse_dates=True, infer_datetime_format=True)

gme_df.head()
# Out:
#                 Date   Close
# 0  1/3/2022 16:00:00  152.84
# 1  1/4/2022 16:00:00  148.91
# 2  1/5/2022 16:00:00  129.37
# 3  1/6/2022 16:00:00  131.03
# 4  1/7/2022 16:00:00  140.62

# %%
# Reading data from 2nd stock - Nvidia
nvda_stock = Path("C:/Users/dejay/Documents/UofT/Fintech Bootcamp/pandas-homework/pandas-homework/nvidia.csv")

nvda_df = pd.read_csv(nvda_stock, parse_dates=True, infer_datetime_format=True)

nvda_df.head()
# Out:
#                 Date   Close
# 0  1/3/2022 16:00:00  301.21
# 1  1/4/2022 16:00:00  292.90
# 2  1/5/2022 16:00:00  276.04
# 3  1/6/2022 16:00:00  281.78
# 4  1/7/2022 16:00:00  272.47

# %%
# Reading data from 3rd stock - Activision Blizzard
atvi_stock = Path("C:/Users/dejay/Documents/UofT/Fintech Bootcamp/pandas-homework/pandas-homework/activisionBlizzard.csv")

atvi_df = pd.read_csv(atvi_stock, parse_dates=True, infer_datetime_format=True)

atvi_df.head()
# Out:
#                 Date  Close
# 0  1/3/2022 16:00:00  67.42
# 1  1/4/2022 16:00:00  67.20
# 2  1/5/2022 16:00:00  66.29
# 3  1/6/2022 16:00:00  63.82
# 4  1/7/2022 16:00:00  64.04

# %%
# Combine all stocks in a single DataFrame
combine_all_returns = pd.concat([gme_df, nvda_df, atvi_df], axis="columns", join="inner")
combine_all_returns.head()
# Out:
#                 Date   Close               Date   Close               Date  \
# 0  1/3/2022 16:00:00  152.84  1/3/2022 16:00:00  301.21  1/3/2022 16:00:00
# 1  1/4/2022 16:00:00  148.91  1/4/2022 16:00:00  292.90  1/4/2022 16:00:00
# 2  1/5/2022 16:00:00  129.37  1/5/2022 16:00:00  276.04  1/5/2022 16:00:00
# 3  1/6/2022 16:00:00  131.03  1/6/2022 16:00:00  281.78  1/6/2022 16:00:00
# 4  1/7/2022 16:00:00  140.62  1/7/2022 16:00:00  272.47  1/7/2022 16:00:00
#
#    Close
# 0  67.42
# 1  67.20
# 2  66.29
# 3  63.82
# 4  64.04

# %%
# Reset Date index
combine_all_returns_df = combine_all_returns.reset_index()
combine_all_returns_df.head()
# Out:
#    index               Date     GME               Date    NVDA  \
# 0      0  1/3/2022 16:00:00  152.84  1/3/2022 16:00:00  301.21
# 1      1  1/4/2022 16:00:00  148.91  1/4/2022 16:00:00  292.90
# 2      2  1/5/2022 16:00:00  129.37  1/5/2022 16:00:00  276.04
# 3      3  1/6/2022 16:00:00  131.03  1/6/2022 16:00:00  281.78
# 4      4  1/7/2022 16:00:00  140.62  1/7/2022 16:00:00  272.47
#
#                 Date   ATVI
# 0  1/3/2022 16:00:00  67.42
# 1  1/4/2022 16:00:00  67.20
# 2  1/5/2022 16:00:00  66.29
# 3  1/6/2022 16:00:00  63.82
# 4  1/7/2022 16:00:00  64.04

# %%
# Reorganize portfolio data by having a column per symbol
combine_all_returns_df = pd.concat([gme_df, nvda_df, atvi_df], axis='columns', join='inner')

combine_all_returns_df.drop('Date', axis=1, inplace=True)
combine_all_returns_df.head()

combine_all_returns_df.columns = (["GME", "NVDA", "ATVI"])
combine_all_returns_df.head()
# Out:
#       GME    NVDA   ATVI
# 0  152.84  301.21  67.42
# 1  148.91  292.90  67.20
# 2  129.37  276.04  66.29
# 3  131.03  281.78  63.82
# 4  140.62  272.47  64.04

# %%
# Calculate daily returns
returns_daily = combine_all_returns_df.pct_change()

# Drop NAs
returns_daily = returns_daily.dropna().copy()

# Display sample data
returns_daily.head()
# Out:
#         GME      NVDA      ATVI
# 1 -0.025713 -0.027589 -0.003263
# 2 -0.131220 -0.057562 -0.013542
# 3  0.012831  0.020794 -0.037261
# 4  0.073189 -0.033040  0.003447
# 5 -0.067345  0.005615 -0.014522

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
return_portfolio = returns_daily.dot(weights)

# Display sample data
return_portfolio.head()
# Out:
# 1   -0.018855
# 2   -0.067441
# 3   -0.001212
# 4    0.014532
# 5   -0.025417
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combine_all_returns_df = pd.concat([return_portfolio, combine_returns], axis='columns', join='inner')
combine_all_returns_df.head()
# Out:
# Empty DataFrame
# Columns: [0, SOROS FUND MANAGEMENT LLC, PAULSON & CO.INC. , TIGER GLOBAL MANAGEMENT LLC, BERKSHIRE HATHAWAY INC, Algo 1, Algo 2, sp]
# Index: []

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combine_all_returns_df.dropna(inplace=True)
combine_all_returns_df
# Out:
# Empty DataFrame
# Columns: [0, SOROS FUND MANAGEMENT LLC, PAULSON & CO.INC. , TIGER GLOBAL MANAGEMENT LLC, BERKSHIRE HATHAWAY INC, Algo 1, Algo 2, sp]
# Index: []

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_deviation = combine_all_returns_df.std() * np.sqrt(252)
annualized_deviation
# Out:
# 0                             NaN
# SOROS FUND MANAGEMENT LLC     NaN
# PAULSON & CO.INC.             NaN
# TIGER GLOBAL MANAGEMENT LLC   NaN
# BERKSHIRE HATHAWAY INC        NaN
# Algo 1                        NaN
# Algo 2                        NaN
# sp                            NaN
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation
combine_all_returns_df.rolling(window=21).std().plot(figsize=[20,10])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combine_all_returns_df.corr().plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
single_covariance = combine_all_returns_df['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combine_returns['sp'])

# Calculate variance of S&P TSX
sp_covariance = combine_all_returns_df['sp'].rolling(window=60).var()

# Computing beta
computing_beta = single_covariance/sp_covariance

# Plot beta trend
computing_beta.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sh_ratios = (combine_all_returns_df.mean() * 252) / (combine_all_returns_df.std() * np.sqrt(252))
sh_ratios
# Out:
# 0                             NaN
# SOROS FUND MANAGEMENT LLC     NaN
# PAULSON & CO.INC.             NaN
# TIGER GLOBAL MANAGEMENT LLC   NaN
# BERKSHIRE HATHAWAY INC        NaN
# Algo 1                        NaN
# Algo 2                        NaN
# sp                            NaN
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sh_ratios.plot(kind = 'bar', title='sh ratio')
# Out:
# <AxesSubplot:title={'center':'sh ratio'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
